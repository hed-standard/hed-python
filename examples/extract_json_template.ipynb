# %% [markdown]
# ## Generate a JSON events sidecar template from a dataset.
#
# General strategy for machine-actionable annotation using HED in BIDS is to create a single `events.json` sidecar file in the BIDS dataset root directory.
# Ideally, this sidecar will contain all the annotations needed for users to understand and analyze the data.
#
# (See the [**BIDS annotation quickstart**](https://www.hed-resources.org/en/latest/BidsAnnotationQuickstart.html) for additional information on this strategy.)
#
# This notebook shows how to create a JSON sidecar template from the information in all the event files in a BIDS dataset. To use this notebook, substitute the specifics of your BIDS dataset for the following variables:
#
# | Variable            | Purpose |
# |---------------------| ------- |
# | `dataset_root` | Full path to root directory of dataset.|
# | `exclude_dirs`      | List of directories to exclude when constructing the list of event files. |
# | `skip_columns`      | List of column names in the `events.tsv` files to skip. |
# | `value_columns`     | List of columns names in the `events.tsv` files to annotate as<br>as a whole rather than by individual column value. |
# | `output_path` | Full path of output file. If None, then output is printed. |
#
# A JSON sidecar appropriate for BIDS (Brain Imaging Data Structure) is generated containing placeholders for the descriptions and HED annotations of the values in the dataset event files. Values in columns that are not designated as `skip_columns` or `value_columns` are considered to contain categorical values, each of which should be annotated individually.
#
# Typical `skip_columns` include the `onset`, `duration`, and `sample` columns, which have well-defined meanings according to BIDS.  The `value_columns` just require a single annotation, applicable to each value in the column.
#
# For additional information see the tutorial [**Create a JSON template**](https://www.hed-resources.org/en/latest/BidsAnnotationQuickstart.html#create-a-json-template) which illustrates the creation of a template from a single event file using the online tools.
#
# Additional information about this notebook can be found in [**Extract JSON template**](https://www.hed-resources.org/en/latest/HedPythonTools.html#extract-json-template) in the HED Python Tools user guide.

# %%
import json
from hed.tools.analysis.tabular_summary import TabularSummary
from hed.tools.util.io_util import get_file_list

dataset_root = '../../../datasets/eeg_ds003645s_hed'
exclude_dirs = ['stimuli', 'code', 'derivatives', 'sourcedata', 'phenotype']
skip_columns = ["onset", "duration", "sample"]
value_columns = ["stim_file", "response_time"]
output_path = None

# Construct the event file dictionary for the BIDS event files
event_files = get_file_list(dataset_root, extensions=[".tsv"], name_suffix="events", exclude_dirs=exclude_dirs)

# Construct the event file value summary and generate a sidecar template representing dataset
value_summary = TabularSummary(value_cols=value_columns, skip_cols=skip_columns, name="Wakeman-Hanson test data")
value_summary.update(event_files)
sidecar_template = value_summary.extract_sidecar_template()
if output_path:
    with open(output_path, "w") as f:
        json.dump(sidecar_template, f, indent=4)
else:
    print(json.dumps(sidecar_template, indent=4))
# Out:
# {
#     "event_type": {
#         "Description": "Description for event_type",
#         "HED": {
#             "double_press": "(Label/event_type, ID/double_press)",
#             "left_press": "(Label/event_type, ID/left_press)",
#             "right_press": "(Label/event_type, ID/right_press)",
#             "setup_right_sym": "(Label/event_type, ID/setup_right_sym)",
#             "show_circle": "(Label/event_type, ID/show_circle)",
#             "show_cross": "(Label/event_type, ID/show_cross)",
#             "show_face": "(Label/event_type, ID/show_face)",
#             "show_face_initial": "(Label/event_type, ID/show_face_initial)"
#         },
#         "Levels": {
#             "double_press": "Here describe column value double_press of column event_type",
#             "left_press": "Here describe column value left_press of column event_type",
#             "right_press": "Here describe column value right_press of column event_type",
#             "setup_right_sym": "Here describe column value setup_right_sym of column event_type",
#             "show_circle": "Here describe column value show_circle of column event_type",
#             "show_cross": "Here describe column value show_cross of column event_type",
#             "show_face": "Here describe column value show_face of column event_type",
#             "show_face_initial": "Here describe column value show_face_initial of column event_type"
#         }
#     },
#     "face_type": {
#         "Description": "Description for face_type",
#         "HED": {
#             "famous_face": "(Label/face_type, ID/famous_face)",
#             "nan": "(Label/face_type, ID/nan)",
#             "scrambled_face": "(Label/face_type, ID/scrambled_face)",
#             "unfamiliar_face": "(Label/face_type, ID/unfamiliar_face)"
#         },
#         "Levels": {
#             "famous_face": "Here describe column value famous_face of column face_type",
#             "nan": "Here describe column value nan of column face_type",
#             "scrambled_face": "Here describe column value scrambled_face of column face_type",
#             "unfamiliar_face": "Here describe column value unfamiliar_face of column face_type"
#         }
#     },
#     "rep_status": {
#         "Description": "Description for rep_status",
#         "HED": {
#             "delayed_repeat": "(Label/rep_status, ID/delayed_repeat)",
#             "first_show": "(Label/rep_status, ID/first_show)",
#             "immediate_repeat": "(Label/rep_status, ID/immediate_repeat)",
#             "nan": "(Label/rep_status, ID/nan)"
#         },
#         "Levels": {
#             "delayed_repeat": "Here describe column value delayed_repeat of column rep_status",
#             "first_show": "Here describe column value first_show of column rep_status",
#             "immediate_repeat": "Here describe column value immediate_repeat of column rep_status",
#             "nan": "Here describe column value nan of column rep_status"
#         }
#     },
#     "trial": {
#         "Description": "Description for trial",
#         "HED": {
#             "1.0": "(Label/trial, ID/1_0)",
#             "10.0": "(Label/trial, ID/10_0)",
#             "11.0": "(Label/trial, ID/11_0)",
#             "12.0": "(Label/trial, ID/12_0)",
#             "13.0": "(Label/trial, ID/13_0)",
#             "14.0": "(Label/trial, ID/14_0)",
#             "15.0": "(Label/trial, ID/15_0)",
#             "16.0": "(Label/trial, ID/16_0)",
#             "17.0": "(Label/trial, ID/17_0)",
#             "18.0": "(Label/trial, ID/18_0)",
#             "19.0": "(Label/trial, ID/19_0)",
#             "2.0": "(Label/trial, ID/2_0)",
#             "20.0": "(Label/trial, ID/20_0)",
#             "21.0": "(Label/trial, ID/21_0)",
#             "22.0": "(Label/trial, ID/22_0)",
#             "23.0": "(Label/trial, ID/23_0)",
#             "24.0": "(Label/trial, ID/24_0)",
#             "25.0": "(Label/trial, ID/25_0)",
#             "26.0": "(Label/trial, ID/26_0)",
#             "27.0": "(Label/trial, ID/27_0)",
#             "28.0": "(Label/trial, ID/28_0)",
#             "29.0": "(Label/trial, ID/29_0)",
#             "3.0": "(Label/trial, ID/3_0)",
#             "30.0": "(Label/trial, ID/30_0)",
#             "31.0": "(Label/trial, ID/31_0)",
#             "32.0": "(Label/trial, ID/32_0)",
#             "33.0": "(Label/trial, ID/33_0)",
#             "34.0": "(Label/trial, ID/34_0)",
#             "35.0": "(Label/trial, ID/35_0)",
#             "36.0": "(Label/trial, ID/36_0)",
#             "37.0": "(Label/trial, ID/37_0)",
#             "38.0": "(Label/trial, ID/38_0)",
#             "39.0": "(Label/trial, ID/39_0)",
#             "4.0": "(Label/trial, ID/4_0)",
#             "40.0": "(Label/trial, ID/40_0)",
#             "41.0": "(Label/trial, ID/41_0)",
#             "42.0": "(Label/trial, ID/42_0)",
#             "43.0": "(Label/trial, ID/43_0)",
#             "44.0": "(Label/trial, ID/44_0)",
#             "45.0": "(Label/trial, ID/45_0)",
#             "46.0": "(Label/trial, ID/46_0)",
#             "47.0": "(Label/trial, ID/47_0)",
#             "48.0": "(Label/trial, ID/48_0)",
#             "49.0": "(Label/trial, ID/49_0)",
#             "5.0": "(Label/trial, ID/5_0)",
#             "50.0": "(Label/trial, ID/50_0)",
#             "51.0": "(Label/trial, ID/51_0)",
#             "52.0": "(Label/trial, ID/52_0)",
#             "53.0": "(Label/trial, ID/53_0)",
#             "54.0": "(Label/trial, ID/54_0)",
#             "55.0": "(Label/trial, ID/55_0)",
#             "56.0": "(Label/trial, ID/56_0)",
#             "57.0": "(Label/trial, ID/57_0)",
#             "6.0": "(Label/trial, ID/6_0)",
#             "7.0": "(Label/trial, ID/7_0)",
#             "8.0": "(Label/trial, ID/8_0)",
#             "9.0": "(Label/trial, ID/9_0)",
#             "nan": "(Label/trial, ID/nan)"
#         },
#         "Levels": {
#             "1.0": "Here describe column value 1.0 of column trial",
#             "10.0": "Here describe column value 10.0 of column trial",
#             "11.0": "Here describe column value 11.0 of column trial",
#             "12.0": "Here describe column value 12.0 of column trial",
#             "13.0": "Here describe column value 13.0 of column trial",
#             "14.0": "Here describe column value 14.0 of column trial",
#             "15.0": "Here describe column value 15.0 of column trial",
#             "16.0": "Here describe column value 16.0 of column trial",
#             "17.0": "Here describe column value 17.0 of column trial",
#             "18.0": "Here describe column value 18.0 of column trial",
#             "19.0": "Here describe column value 19.0 of column trial",
#             "2.0": "Here describe column value 2.0 of column trial",
#             "20.0": "Here describe column value 20.0 of column trial",
#             "21.0": "Here describe column value 21.0 of column trial",
#             "22.0": "Here describe column value 22.0 of column trial",
#             "23.0": "Here describe column value 23.0 of column trial",
#             "24.0": "Here describe column value 24.0 of column trial",
#             "25.0": "Here describe column value 25.0 of column trial",
#             "26.0": "Here describe column value 26.0 of column trial",
#             "27.0": "Here describe column value 27.0 of column trial",
#             "28.0": "Here describe column value 28.0 of column trial",
#             "29.0": "Here describe column value 29.0 of column trial",
#             "3.0": "Here describe column value 3.0 of column trial",
#             "30.0": "Here describe column value 30.0 of column trial",
#             "31.0": "Here describe column value 31.0 of column trial",
#             "32.0": "Here describe column value 32.0 of column trial",
#             "33.0": "Here describe column value 33.0 of column trial",
#             "34.0": "Here describe column value 34.0 of column trial",
#             "35.0": "Here describe column value 35.0 of column trial",
#             "36.0": "Here describe column value 36.0 of column trial",
#             "37.0": "Here describe column value 37.0 of column trial",
#             "38.0": "Here describe column value 38.0 of column trial",
#             "39.0": "Here describe column value 39.0 of column trial",
#             "4.0": "Here describe column value 4.0 of column trial",
#             "40.0": "Here describe column value 40.0 of column trial",
#             "41.0": "Here describe column value 41.0 of column trial",
#             "42.0": "Here describe column value 42.0 of column trial",
#             "43.0": "Here describe column value 43.0 of column trial",
#             "44.0": "Here describe column value 44.0 of column trial",
#             "45.0": "Here describe column value 45.0 of column trial",
#             "46.0": "Here describe column value 46.0 of column trial",
#             "47.0": "Here describe column value 47.0 of column trial",
#             "48.0": "Here describe column value 48.0 of column trial",
#             "49.0": "Here describe column value 49.0 of column trial",
#             "5.0": "Here describe column value 5.0 of column trial",
#             "50.0": "Here describe column value 50.0 of column trial",
#             "51.0": "Here describe column value 51.0 of column trial",
#             "52.0": "Here describe column value 52.0 of column trial",
#             "53.0": "Here describe column value 53.0 of column trial",
#             "54.0": "Here describe column value 54.0 of column trial",
#             "55.0": "Here describe column value 55.0 of column trial",
#             "56.0": "Here describe column value 56.0 of column trial",
#             "57.0": "Here describe column value 57.0 of column trial",
#             "6.0": "Here describe column value 6.0 of column trial",
#             "7.0": "Here describe column value 7.0 of column trial",
#             "8.0": "Here describe column value 8.0 of column trial",
#             "9.0": "Here describe column value 9.0 of column trial",
#             "nan": "Here describe column value nan of column trial"
#         }
#     },
#     "rep_lag": {
#         "Description": "Description for rep_lag",
#         "HED": {
#             "1.0": "(Label/rep_lag, ID/1_0)",
#             "10.0": "(Label/rep_lag, ID/10_0)",
#             "11.0": "(Label/rep_lag, ID/11_0)",
#             "12.0": "(Label/rep_lag, ID/12_0)",
#             "13.0": "(Label/rep_lag, ID/13_0)",
#             "14.0": "(Label/rep_lag, ID/14_0)",
#             "15.0": "(Label/rep_lag, ID/15_0)",
#             "6.0": "(Label/rep_lag, ID/6_0)",
#             "7.0": "(Label/rep_lag, ID/7_0)",
#             "8.0": "(Label/rep_lag, ID/8_0)",
#             "9.0": "(Label/rep_lag, ID/9_0)",
#             "nan": "(Label/rep_lag, ID/nan)"
#         },
#         "Levels": {
#             "1.0": "Here describe column value 1.0 of column rep_lag",
#             "10.0": "Here describe column value 10.0 of column rep_lag",
#             "11.0": "Here describe column value 11.0 of column rep_lag",
#             "12.0": "Here describe column value 12.0 of column rep_lag",
#             "13.0": "Here describe column value 13.0 of column rep_lag",
#             "14.0": "Here describe column value 14.0 of column rep_lag",
#             "15.0": "Here describe column value 15.0 of column rep_lag",
#             "6.0": "Here describe column value 6.0 of column rep_lag",
#             "7.0": "Here describe column value 7.0 of column rep_lag",
#             "8.0": "Here describe column value 8.0 of column rep_lag",
#             "9.0": "Here describe column value 9.0 of column rep_lag",
#             "nan": "Here describe column value nan of column rep_lag"
#         }
#     },
#     "value": {
#         "Description": "Description for value",
#         "HED": {
#             "0": "(Label/value, ID/0)",
#             "1": "(Label/value, ID/1)",
#             "13": "(Label/value, ID/13)",
#             "14": "(Label/value, ID/14)",
#             "15": "(Label/value, ID/15)",
#             "17": "(Label/value, ID/17)",
#             "18": "(Label/value, ID/18)",
#             "19": "(Label/value, ID/19)",
#             "256": "(Label/value, ID/256)",
#             "3": "(Label/value, ID/3)",
#             "4096": "(Label/value, ID/4096)",
#             "4352": "(Label/value, ID/4352)",
#             "5": "(Label/value, ID/5)",
#             "6": "(Label/value, ID/6)",
#             "7": "(Label/value, ID/7)"
#         },
#         "Levels": {
#             "0": "Here describe column value 0 of column value",
#             "1": "Here describe column value 1 of column value",
#             "13": "Here describe column value 13 of column value",
#             "14": "Here describe column value 14 of column value",
#             "15": "Here describe column value 15 of column value",
#             "17": "Here describe column value 17 of column value",
#             "18": "Here describe column value 18 of column value",
#             "19": "Here describe column value 19 of column value",
#             "256": "Here describe column value 256 of column value",
#             "3": "Here describe column value 3 of column value",
#             "4096": "Here describe column value 4096 of column value",
#             "4352": "Here describe column value 4352 of column value",
#             "5": "Here describe column value 5 of column value",
#             "6": "Here describe column value 6 of column value",
#             "7": "Here describe column value 7 of column value"
#         }
#     },
#     "stim_file": {
#         "Description": "Description for stim_file",
#         "HED": "(Label/stim_file, ID/#)"
#     },
#     "response_time": {
#         "Description": "Description for response_time",
#         "HED": "(Label/response_time, ID/#)"
#     }
# }
