# %% [markdown]
# ## Preliminary summary of the Attention Shift dataset
#
# This script does a preliminary summary of the contents of the events files.
# The summary includes printing out the column names of each event file so
# that they can be manually checked for differences.
#
# The script assumes that the data is in BIDS format and that each BIDS events
# file of the form `_events.tsv` has a corresponding events file with
# suffix `_events_temp.tsv` that was previously dumped from the `EEG.set` files.
#
# In order to compare the events coming from the BIDS events files and those
# from the EEG.set files, the script creates dictionaries of `key` to full path
# for each type of file.  The `key` is of the form `sub-xxx_run-y` which
# uniquely specify each event file in the dataset. If a dataset contains
# multiple sessions for each subject, the `key` should include additional
# parts of the file name to uniquely specify each subject.

# %%
bids_root_path = 'G:/AttentionShift/AttentionShiftExperiments'
bids_skip = ['onset', 'duration', 'sample', 'stim_file', 'HED']
eeg_skip = ['latency', 'urevent', 'usertags', 'sample_offset']

# %%
from hed.tools.io_utils import get_file_list, make_file_dict

# Construct the dictionary for BIDS events files
files_bids = get_file_list(bids_root_path, extensions=[".tsv"], name_suffix="_events")
dict_bids = make_file_dict(files_bids)
print(f"\n{len(list(dict_bids))} Sternberg BIDS style event files")
for key, value in dict_bids.items():
    print(f"{key}: {value}")

# Construct the dictionary for EEG.event files
files_eeg = get_file_list(bids_root_path, extensions=[".tsv"], name_suffix="_events_temp")
dict_eeg = make_file_dict(files_eeg, indices=(0, -3))
print(f"\n{len(list(dict_eeg))} Sternberg EEG.event style event files")
for key, value in dict_eeg.items():
    print(f"{key}: {value}")
# Out:
# 54 Sternberg BIDS style event files
# sub-001_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-001\eeg\sub-001_task-AuditoryVisualShift_run-01_events.tsv
# sub-002_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-002\eeg\sub-002_task-AuditoryVisualShift_run-01_events.tsv
# sub-003_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-003\eeg\sub-003_task-AuditoryVisualShift_run-01_events.tsv
# sub-004_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-004\eeg\sub-004_task-AuditoryVisualShift_run-01_events.tsv
# sub-004_run-02: G:/AttentionShift/AttentionShiftExperiments\sub-004\eeg\sub-004_task-AuditoryVisualShift_run-02_events.tsv
# sub-005_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-005\eeg\sub-005_task-AuditoryVisualShift_run-01_events.tsv
# sub-006_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-006\eeg\sub-006_task-AuditoryVisualShift_run-01_events.tsv
# sub-007_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-007\eeg\sub-007_task-AuditoryVisualShift_run-01_events.tsv
# sub-008_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-008\eeg\sub-008_task-AuditoryVisualShift_run-01_events.tsv
# sub-009_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-009\eeg\sub-009_task-AuditoryVisualShift_run-01_events.tsv
# sub-010_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-010\eeg\sub-010_task-AuditoryVisualShift_run-01_events.tsv
# sub-011_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-011\eeg\sub-011_task-AuditoryVisualShift_run-01_events.tsv
# sub-012_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-012\eeg\sub-012_task-AuditoryVisualShift_run-01_events.tsv
# sub-013_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-013\eeg\sub-013_task-AuditoryVisualShift_run-01_events.tsv
# sub-014_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-014\eeg\sub-014_task-AuditoryVisualShift_run-01_events.tsv
# sub-015_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-015\eeg\sub-015_task-AuditoryVisualShift_run-01_events.tsv
# sub-016_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-016\eeg\sub-016_task-AuditoryVisualShift_run-01_events.tsv
# sub-017_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-017\eeg\sub-017_task-AuditoryVisualShift_run-01_events.tsv
# sub-018_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-018\eeg\sub-018_task-AuditoryVisualShift_run-01_events.tsv
# sub-019_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-019\eeg\sub-019_task-AuditoryVisualShift_run-01_events.tsv
# sub-020_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-020\eeg\sub-020_task-AuditoryVisualShift_run-01_events.tsv
# sub-021_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-021\eeg\sub-021_task-AuditoryVisualShift_run-01_events.tsv
# sub-021_run-02: G:/AttentionShift/AttentionShiftExperiments\sub-021\eeg\sub-021_task-AuditoryVisualShift_run-02_events.tsv
# sub-022_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-022\eeg\sub-022_task-AuditoryVisualShift_run-01_events.tsv
# sub-022_run-02: G:/AttentionShift/AttentionShiftExperiments\sub-022\eeg\sub-022_task-AuditoryVisualShift_run-02_events.tsv
# sub-023_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-023\eeg\sub-023_task-AuditoryVisualShift_run-01_events.tsv
# sub-024_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-024\eeg\sub-024_task-AuditoryVisualShift_run-01_events.tsv
# sub-025_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-025\eeg\sub-025_task-AuditoryVisualShift_run-01_events.tsv
# sub-026_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-026\eeg\sub-026_task-AuditoryVisualShift_run-01_events.tsv
# sub-027_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-027\eeg\sub-027_task-AuditoryVisualShift_run-01_events.tsv
# sub-028_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-028\eeg\sub-028_task-AuditoryVisualShift_run-01_events.tsv
# sub-028_run-02: G:/AttentionShift/AttentionShiftExperiments\sub-028\eeg\sub-028_task-AuditoryVisualShift_run-02_events.tsv
# sub-029_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-029\eeg\sub-029_task-AuditoryVisualShift_run-01_events.tsv
# sub-030_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-030\eeg\sub-030_task-AuditoryVisualShift_run-01_events.tsv
# sub-031_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-031\eeg\sub-031_task-AuditoryVisualShift_run-01_events.tsv
# sub-032_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-032\eeg\sub-032_task-AuditoryVisualShift_run-01_events.tsv
# sub-033_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-033\eeg\sub-033_task-AuditoryVisualShift_run-01_events.tsv
# sub-034_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-034\eeg\sub-034_task-AuditoryVisualShift_run-01_events.tsv
# sub-035_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-035\eeg\sub-035_task-AuditoryVisualShift_run-01_events.tsv
# sub-036_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-036\eeg\sub-036_task-AuditoryVisualShift_run-01_events.tsv
# sub-036_run-02: G:/AttentionShift/AttentionShiftExperiments\sub-036\eeg\sub-036_task-AuditoryVisualShift_run-02_events.tsv
# sub-037_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-037\eeg\sub-037_task-AuditoryVisualShift_run-01_events.tsv
# sub-038_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-038\eeg\sub-038_task-AuditoryVisualShift_run-01_events.tsv
# sub-039_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-039\eeg\sub-039_task-AuditoryVisualShift_run-01_events.tsv
# sub-040_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-040\eeg\sub-040_task-AuditoryVisualShift_run-01_events.tsv
# sub-041_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-041\eeg\sub-041_task-AuditoryVisualShift_run-01_events.tsv
# sub-042_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-042\eeg\sub-042_task-AuditoryVisualShift_run-01_events.tsv
# sub-043_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-043\eeg\sub-043_task-AuditoryVisualShift_run-01_events.tsv
# sub-044_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-044\eeg\sub-044_task-AuditoryVisualShift_run-01_events.tsv
# sub-045_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-045\eeg\sub-045_task-AuditoryVisualShift_run-01_events.tsv
# sub-046_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-046\eeg\sub-046_task-AuditoryVisualShift_run-01_events.tsv
# sub-047_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-047\eeg\sub-047_task-AuditoryVisualShift_run-01_events.tsv
# sub-048_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-048\eeg\sub-048_task-AuditoryVisualShift_run-01_events.tsv
# sub-049_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-049\eeg\sub-049_task-AuditoryVisualShift_run-01_events.tsv
#
# 54 Sternberg EEG.event style event files
# sub-001_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-001\eeg\sub-001_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-002_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-002\eeg\sub-002_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-003_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-003\eeg\sub-003_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-004_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-004\eeg\sub-004_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-004_run-02: G:/AttentionShift/AttentionShiftExperiments\sub-004\eeg\sub-004_task-AuditoryVisualShift_run-02_events_temp.tsv
# sub-005_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-005\eeg\sub-005_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-006_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-006\eeg\sub-006_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-007_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-007\eeg\sub-007_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-008_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-008\eeg\sub-008_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-009_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-009\eeg\sub-009_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-010_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-010\eeg\sub-010_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-011_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-011\eeg\sub-011_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-012_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-012\eeg\sub-012_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-013_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-013\eeg\sub-013_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-014_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-014\eeg\sub-014_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-015_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-015\eeg\sub-015_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-016_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-016\eeg\sub-016_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-017_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-017\eeg\sub-017_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-018_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-018\eeg\sub-018_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-019_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-019\eeg\sub-019_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-020_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-020\eeg\sub-020_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-021_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-021\eeg\sub-021_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-021_run-02: G:/AttentionShift/AttentionShiftExperiments\sub-021\eeg\sub-021_task-AuditoryVisualShift_run-02_events_temp.tsv
# sub-022_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-022\eeg\sub-022_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-022_run-02: G:/AttentionShift/AttentionShiftExperiments\sub-022\eeg\sub-022_task-AuditoryVisualShift_run-02_events_temp.tsv
# sub-023_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-023\eeg\sub-023_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-024_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-024\eeg\sub-024_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-025_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-025\eeg\sub-025_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-026_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-026\eeg\sub-026_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-027_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-027\eeg\sub-027_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-028_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-028\eeg\sub-028_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-028_run-02: G:/AttentionShift/AttentionShiftExperiments\sub-028\eeg\sub-028_task-AuditoryVisualShift_run-02_events_temp.tsv
# sub-029_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-029\eeg\sub-029_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-030_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-030\eeg\sub-030_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-031_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-031\eeg\sub-031_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-032_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-032\eeg\sub-032_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-033_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-033\eeg\sub-033_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-034_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-034\eeg\sub-034_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-035_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-035\eeg\sub-035_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-036_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-036\eeg\sub-036_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-036_run-02: G:/AttentionShift/AttentionShiftExperiments\sub-036\eeg\sub-036_task-AuditoryVisualShift_run-02_events_temp.tsv
# sub-037_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-037\eeg\sub-037_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-038_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-038\eeg\sub-038_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-039_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-039\eeg\sub-039_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-040_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-040\eeg\sub-040_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-041_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-041\eeg\sub-041_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-042_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-042\eeg\sub-042_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-043_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-043\eeg\sub-043_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-044_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-044\eeg\sub-044_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-045_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-045\eeg\sub-045_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-046_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-046\eeg\sub-046_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-047_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-047\eeg\sub-047_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-048_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-048\eeg\sub-048_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-049_run-01: G:/AttentionShift/AttentionShiftExperiments\sub-049\eeg\sub-049_task-AuditoryVisualShift_run-01_events_temp.tsv

# %%
from hed.tools.data_utils import get_new_dataframe

print(f"\nBIDS style event file columns:")
for key, file in dict_bids.items():
    df = get_new_dataframe(file)
    print(f"{key}: {str(list(df.columns.values))}")

print(f"\nEEG.event style event file columns:")
for key, file in dict_eeg.items():
    df = get_new_dataframe(file)
    print(f"{key}: {str(list(df.columns.values))}")
# Out:
# BIDS style event file columns:
# sub-001_run-01: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-002_run-01: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-003_run-01: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-004_run-01: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-004_run-02: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-005_run-01: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-006_run-01: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-007_run-01: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-008_run-01: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-009_run-01: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-010_run-01: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-011_run-01: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-012_run-01: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-013_run-01: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-014_run-01: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-015_run-01: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-016_run-01: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-017_run-01: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-018_run-01: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-019_run-01: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-020_run-01: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-021_run-01: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-021_run-02: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-022_run-01: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-022_run-02: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-023_run-01: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-024_run-01: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-025_run-01: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-026_run-01: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-027_run-01: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-028_run-01: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-028_run-02: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-029_run-01: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-030_run-01: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-031_run-01: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-032_run-01: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-033_run-01: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-034_run-01: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-035_run-01: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-036_run-01: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-036_run-02: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-037_run-01: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-038_run-01: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-039_run-01: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-040_run-01: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-041_run-01: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-042_run-01: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-043_run-01: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-044_run-01: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-045_run-01: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-046_run-01: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-047_run-01: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-048_run-01: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-049_run-01: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
#
# EEG.event style event file columns:
# sub-001_run-01: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-002_run-01: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-003_run-01: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-004_run-01: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-004_run-02: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-005_run-01: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-006_run-01: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-007_run-01: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-008_run-01: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-009_run-01: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-010_run-01: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-011_run-01: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-012_run-01: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-013_run-01: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-014_run-01: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-015_run-01: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-016_run-01: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-017_run-01: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-018_run-01: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-019_run-01: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-020_run-01: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-021_run-01: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-021_run-02: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-022_run-01: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-022_run-02: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-023_run-01: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-024_run-01: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-025_run-01: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-026_run-01: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-027_run-01: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-028_run-01: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-028_run-02: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-029_run-01: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-030_run-01: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-031_run-01: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-032_run-01: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-033_run-01: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-034_run-01: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-035_run-01: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-036_run-01: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-036_run-02: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-037_run-01: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-038_run-01: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-039_run-01: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-040_run-01: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-041_run-01: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-042_run-01: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-043_run-01: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-044_run-01: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-045_run-01: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-046_run-01: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-047_run-01: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-048_run-01: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-049_run-01: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']

# %%
from hed.tools.map_utils import make_combined_dicts

print('\nBIDS events summary:')
bids_counts_all, bids_counts =  make_combined_dicts(dict_bids, skip_cols=bids_skip)
bids_counts_all.print()

print('\nEEG.event events summary:')
eeg_counts_all, eeg_counts =  make_combined_dicts(dict_eeg, skip_cols=eeg_skip)
eeg_counts_all.print()
# Out:
# BIDS events summary:
# Summary for column dictionary :
#   Categorical columns (3):
#     response_time (1 distinct values):
#       n/a: 287333
#     trial_type (4 distinct values):
#       0: 6264
#       1: 58184
#       2: 54045
#       3: 168840
#     value (52 distinct values):
#       1: 240
#       10: 96
#       11: 3179
#       110: 96
#       111: 766
#       112: 766
#       113: 384
#       114: 382
#       12: 3173
#       1201: 5075
#       13: 4909
#       14: 4907
#       15: 18089
#       16: 18090
#       17: 192
#       18: 192
#       19: 96
#       199: 197
#       2: 240
#       201: 764
#       202: 928
#       21: 2242
#       212: 3
#       22: 2245
#       2201: 4545
#       23: 4484
#       24: 4489
#       25: 17927
#       26: 17923
#       28: 2
#       3: 192
#       31: 6810
#       310: 4510
#       311: 36014
#       312: 35989
#       313: 18009
#       314: 18014
#       32: 6809
#       3201: 18644
#       33: 96
#       34: 96
#       35: 383
#       36: 385
#       37: 9022
#       38: 9022
#       39: 4504
#       4: 192
#       5: 772
#       6: 769
#       7: 192
#       8: 192
#       9: 96
#   Value columns (0):
#
# EEG.event events summary:
# Summary for column dictionary :
#   Categorical columns (3):
#     cond_code (4 distinct values):
#       0: 6264
#       1: 58184
#       2: 54045
#       3: 168840
#     event_code (17 distinct values):
#       1: 11703
#       10: 4702
#       11: 37548
#       12: 37524
#       13: 18778
#       14: 18779
#       199: 197
#       2: 11701
#       201: 29028
#       202: 928
#       3: 9296
#       4: 9301
#       5: 37171
#       6: 37167
#       7: 9406
#       8: 9408
#       9: 4696
#     type (52 distinct values):
#       1: 240
#       10: 96
#       11: 3179
#       110: 96
#       111: 766
#       112: 766
#       113: 384
#       114: 382
#       12: 3173
#       1201: 5075
#       13: 4909
#       14: 4907
#       15: 18089
#       16: 18090
#       17: 192
#       18: 192
#       19: 96
#       199: 197
#       2: 240
#       201: 764
#       202: 928
#       21: 2242
#       212: 3
#       22: 2245
#       2201: 4545
#       23: 4484
#       24: 4489
#       25: 17927
#       26: 17923
#       28: 2
#       3: 192
#       31: 6810
#       310: 4510
#       311: 36014
#       312: 35989
#       313: 18009
#       314: 18014
#       32: 6809
#       3201: 18644
#       33: 96
#       34: 96
#       35: 383
#       36: 385
#       37: 9022
#       38: 9022
#       39: 4504
#       4: 192
#       5: 772
#       6: 769
#       7: 192
#       8: 192
#       9: 96
#   Value columns (0):
