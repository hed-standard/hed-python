# %% [markdown]
# ## Analyze WH events
#
# This script summarizes the event structures in the W-H-MEEG dataset
# for consistency and potential remapping.  The script assumes that
# an extra set of event files `_events_temp.tsv` has been dumped
# from the `.set` MEEG files so that consistency of the two event
# representation can be checked.

# %%
bids_root_path = 'G:/WH_working'

# %%
from hed.tools import get_file_list

event_files_bids = get_file_list(bids_root_path, types=[".tsv"], suffix="_events")
event_files_eeg = get_file_list(bids_root_path, types=[".tsv"], suffix="_events_temp")
bids_skip = ['onset', 'duration', 'sample', 'response_time', 'stim_file', 'HED']
eeg_skip = ['latency', 'urevent', 'sample_offset', 'stim_file']

# %% [markdown]
# We print out the column names of each event file to make sure uniform.

# %%
import os
from hed.tools import get_new_dataframe

bids_file_dict = {}
print(f"\nBIDS form of the events: {len(event_files_bids)}")
for file in event_files_bids:
    base = os.path.basename(file)
    pieces = base.split('_')
    key = f"{pieces[0]}_{pieces[-2]}"
    df = get_new_dataframe(file)
    bids_file_dict[key] = file
    print(f"{key}: {str(list(df.columns.values))}")
# Out:
# BIDS form of the events: 108
# sub-002_run-1: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-002_run-2: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-002_run-3: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-002_run-4: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-002_run-5: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-002_run-6: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-003_run-1: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-003_run-2: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-003_run-3: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-003_run-4: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-003_run-5: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-003_run-6: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-004_run-1: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-004_run-2: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-004_run-3: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-004_run-4: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-004_run-5: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-004_run-6: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-005_run-1: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-005_run-2: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-005_run-3: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-005_run-4: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-005_run-5: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-005_run-6: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-006_run-1: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-006_run-2: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-006_run-3: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-006_run-4: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-006_run-5: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-006_run-6: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-007_run-1: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-007_run-2: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-007_run-3: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-007_run-4: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-007_run-5: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-007_run-6: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-008_run-1: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-008_run-2: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-008_run-3: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-008_run-4: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-008_run-5: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-008_run-6: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-009_run-1: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-009_run-2: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-009_run-3: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-009_run-4: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-009_run-5: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-009_run-6: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-010_run-1: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-010_run-2: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-010_run-3: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-010_run-4: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-010_run-5: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-010_run-6: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-011_run-1: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-011_run-2: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-011_run-3: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-011_run-4: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-011_run-5: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-011_run-6: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-012_run-1: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-012_run-2: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-012_run-3: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-012_run-4: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-012_run-5: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-012_run-6: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-013_run-1: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-013_run-2: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-013_run-3: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-013_run-4: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-013_run-5: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-013_run-6: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-014_run-1: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-014_run-2: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-014_run-3: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-014_run-4: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-014_run-5: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-014_run-6: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-015_run-1: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-015_run-2: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-015_run-3: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-015_run-4: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-015_run-5: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-015_run-6: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-016_run-1: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-016_run-2: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-016_run-3: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-016_run-4: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-016_run-5: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-016_run-6: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-017_run-1: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-017_run-2: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-017_run-3: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-017_run-4: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-017_run-5: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-017_run-6: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-018_run-1: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-018_run-2: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-018_run-3: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-018_run-4: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-018_run-5: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-018_run-6: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-019_run-1: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-019_run-2: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-019_run-3: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-019_run-4: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-019_run-5: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']
# sub-019_run-6: ['onset', 'duration', 'sample', 'event_type', 'face_type', 'repetition_type', 'trial', 'trial_lag', 'trigger', 'stim_file']

# %%
eeg_file_dict = {}
print(f"\nEEG form of the events: {len(event_files_eeg)} files")
for file in event_files_eeg:
    base = os.path.basename(file)
    pieces = base.split('_')
    key = f"{pieces[0]}_{pieces[-3]}"
    df = get_new_dataframe(file)
    eeg_file_dict[key] = file
    print(f"{key}: {str(list(df.columns.values))}")
# Out:
# EEG form of the events: 108 files
# sub-002_run-1: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-002_run-2: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-002_run-3: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-002_run-4: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-002_run-5: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-002_run-6: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-003_run-1: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-003_run-2: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-003_run-3: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-003_run-4: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-003_run-5: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-003_run-6: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-004_run-1: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-004_run-2: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-004_run-3: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-004_run-4: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-004_run-5: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-004_run-6: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-005_run-1: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-005_run-2: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-005_run-3: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-005_run-4: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-005_run-5: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-005_run-6: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-006_run-1: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-006_run-2: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-006_run-3: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-006_run-4: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-006_run-5: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-006_run-6: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-007_run-1: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-007_run-2: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-007_run-3: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-007_run-4: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-007_run-5: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-007_run-6: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-008_run-1: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-008_run-2: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-008_run-3: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-008_run-4: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-008_run-5: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-008_run-6: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-009_run-1: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-009_run-2: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-009_run-3: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-009_run-4: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-009_run-5: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-009_run-6: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-010_run-1: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-010_run-2: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-010_run-3: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-010_run-4: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-010_run-5: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-010_run-6: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-011_run-1: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-011_run-2: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-011_run-3: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-011_run-4: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-011_run-5: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-011_run-6: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-012_run-1: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-012_run-2: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-012_run-3: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-012_run-4: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-012_run-5: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-012_run-6: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-013_run-1: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-013_run-2: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-013_run-3: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-013_run-4: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-013_run-5: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-013_run-6: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-014_run-1: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-014_run-2: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-014_run-3: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-014_run-4: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-014_run-5: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-014_run-6: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-015_run-1: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-015_run-2: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-015_run-3: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-015_run-4: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-015_run-5: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-015_run-6: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-016_run-1: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-016_run-2: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-016_run-3: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-016_run-4: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-016_run-5: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-016_run-6: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-017_run-1: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-017_run-2: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-017_run-3: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-017_run-4: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-017_run-5: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-017_run-6: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-018_run-1: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-018_run-2: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-018_run-3: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-018_run-4: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-018_run-5: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-018_run-6: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-019_run-1: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-019_run-2: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-019_run-3: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-019_run-4: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-019_run-5: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']
# sub-019_run-6: ['latency', 'type', 'stim_file', 'face_type', 'trigger', 'repetition_type']

# %%
from hed.tools import ColumnDict
bids_dicts_all = ColumnDict(skip_cols=bids_skip, name=f"{bids_root_path} BIDS" )
bids_dicts = {}
for key, file in bids_file_dict.items():
    orig_dict = ColumnDict(skip_cols=bids_skip, name=f"{file} BIDS")
    orig_dict.update(file)
    bids_dicts[key] = orig_dict
    bids_dicts_all.update_dict(orig_dict)
bids_dicts_all.print()
# Out:
# Summary for column dictionary G:/WH_working BIDS:
#   Categorical columns (6):
#     event_type (9 distinct values):
#       double_press: 14
#       left_press: 6911
#       left_sym: 48
#       right_press: 8507
#       right_sym: 60
#       setup: 108
#       show_circle: 15946
#       show_cross: 15939
#       show_face: 15929
#     face_type (4 distinct values):
#       famous_face: 5304
#       n/a: 47533
#       scrambled_face: 5305
#       unfamiliar_face: 5320
#     repetition_type (4 distinct values):
#       delayed_repeat: 3941
#       first_show: 8100
#       immediate_repeat: 3888
#       n/a: 47533
#     trial (152 distinct values):
#       1: 319
#       10: 427
#       100: 428
#       101: 428
#       102: 431
#       103: 426
#       104: 428
#       105: 427
#       106: 428
#       107: 430
#       108: 429
#       109: 428
#       11: 428
#       110: 430
#       111: 426
#       112: 428
#       113: 432
#       114: 431
#       115: 430
#       116: 428
#       117: 426
#       118: 428
#       119: 429
#       12: 428
#       120: 427
#       121: 431
#       122: 418
#       123: 426
#       124: 426
#       125: 430
#       126: 430
#       127: 427
#       128: 428
#       129: 427
#       13: 430
#       130: 425
#       131: 428
#       132: 423
#       133: 425
#       134: 429
#       135: 429
#       136: 428
#       137: 429
#       138: 427
#       139: 428
#       14: 430
#       140: 430
#       141: 430
#       142: 430
#       143: 428
#       144: 426
#       145: 427
#       146: 422
#       147: 389
#       148: 270
#       149: 116
#       15: 428
#       150: 29
#       151: 4
#       16: 428
#       17: 431
#       18: 430
#       19: 427
#       2: 430
#       20: 433
#       21: 428
#       22: 428
#       23: 428
#       24: 428
#       25: 431
#       26: 431
#       27: 426
#       28: 427
#       29: 430
#       3: 428
#       30: 429
#       31: 429
#       32: 427
#       33: 430
#       34: 431
#       35: 431
#       36: 428
#       37: 429
#       38: 428
#       39: 430
#       4: 428
#       40: 427
#       41: 431
#       42: 427
#       43: 429
#       44: 431
#       45: 429
#       46: 429
#       47: 428
#       48: 430
#       49: 425
#       5: 429
#       50: 429
#       51: 428
#       52: 429
#       53: 429
#       54: 430
#       55: 430
#       56: 429
#       57: 430
#       58: 429
#       59: 430
#       6: 427
#       60: 431
#       61: 430
#       62: 428
#       63: 431
#       64: 424
#       65: 430
#       66: 432
#       67: 423
#       68: 431
#       69: 431
#       7: 428
#       70: 430
#       71: 429
#       72: 428
#       73: 427
#       74: 430
#       75: 428
#       76: 431
#       77: 429
#       78: 429
#       79: 428
#       8: 428
#       80: 428
#       81: 429
#       82: 425
#       83: 431
#       84: 428
#       85: 428
#       86: 430
#       87: 429
#       88: 430
#       89: 429
#       9: 425
#       90: 428
#       91: 429
#       92: 431
#       93: 416
#       94: 433
#       95: 429
#       96: 428
#       97: 428
#       98: 427
#       99: 427
#       n/a: 216
#     trial_lag (14 distinct values):
#       1: 3884
#       10: 816
#       11: 905
#       12: 763
#       13: 441
#       14: 177
#       15: 53
#       16: 4
#       2: 4
#       6: 10
#       7: 69
#       8: 223
#       9: 480
#       n/a: 55633
#     trigger (14 distinct values):
#       0: 15946
#       13: 2700
#       14: 1304
#       15: 1316
#       17: 2700
#       18: 1271
#       19: 1334
#       256: 6911
#       4096: 8507
#       4352: 14
#       5: 2700
#       6: 1313
#       7: 1291
#       n/a: 16155
#   Value columns (0):

# %%
from hed.tools import ColumnDict
eeg_dicts_all = ColumnDict(skip_cols=eeg_skip, name=f"{bids_root_path} EEG" )
eeg_dicts = {}
for key, file in eeg_file_dict.items():
    eeg_dict = ColumnDict(skip_cols=eeg_skip, name=f"{file} EEG")
    eeg_dict.update(file)
    eeg_dicts[key] = eeg_dict
    eeg_dicts_all.update_dict(eeg_dict)
eeg_dicts_all.print()
# Out:
# Summary for column dictionary G:/WH_working EEG:
#   Categorical columns (4):
#     face_type (4 distinct values):
#       famous_face: 5304
#       n/a: 47533
#       scrambled_face: 5305
#       unfamiliar_face: 5320
#     repetition_type (4 distinct values):
#       delayed_repeat: 3941
#       first_show: 8100
#       immediate_repeat: 3888
#       n/a: 47533
#     trigger (14 distinct values):
#       0: 15946
#       13: 2700
#       14: 1304
#       15: 1316
#       17: 2700
#       18: 1271
#       19: 1334
#       256: 6911
#       4096: 8507
#       4352: 14
#       5: 2700
#       6: 1313
#       7: 1291
#       n/a: 16155
#     type (9 distinct values):
#       4352: 14
#       left_press: 6911
#       left_sym: 48
#       right_press: 8507
#       right_sym: 60
#       setup: 108
#       show_circle: 15946
#       show_cross: 15939
#       show_face: 15929
#   Value columns (0):

# %% [markdown]
# Make the following changes to the BIDS events files:
#
# 1. Rename `trial_lag` as `rep_lag`.
# 2. Rename `repetition_type` as `rep_type`.
# 3. Rename `trigger` as `value`.
# 4. Remove the first data row of each file.
# 5. Rename `right_sym` in new first row of `event_type` column to be `setup_right_sym`.
# 6. Rename `left_sym` in new first row of `event_type` column to be `setup_left_sym`.
# 7. Save as `_events_temp2.tsv`

# %%
bids_file_dict = {}
print(f"\nBIDS form of the events: {len(event_files_bids)}")
for my_file in event_files_bids:
    print(my_file)
    df = get_new_dataframe(my_file)
    df.rename(columns={"trial_lag": "rep_lag", "repetition_type": "rep_status", "trigger":"value"}, inplace=True)
    df.drop([0], inplace=True)

    if  df.loc[df.index[0], 'event_type']== 'right_sym':
         df.loc[df.index[0], 'event_type'] = 'setup_right_sym'
    elif  df.loc[df.index[0], 'event_type']== 'left_sym':
         df.loc[df.index[0], 'event_type'] = 'setup_right_sym'
    else:
        print(f"...bad first line in {my_file}")
    filename = my_file[:-4] + "_temp2.tsv"
    print(filename)
    df.to_csv(filename, sep='\t', index=False)
# Out:
# BIDS form of the events: 108
# G:/WH_working\sub-002\eeg\sub-002_task-FacePerception_run-1_events.tsv
# G:/WH_working\sub-002\eeg\sub-002_task-FacePerception_run-1_events_temp2.tsv
# G:/WH_working\sub-002\eeg\sub-002_task-FacePerception_run-2_events.tsv
# G:/WH_working\sub-002\eeg\sub-002_task-FacePerception_run-2_events_temp2.tsv
# G:/WH_working\sub-002\eeg\sub-002_task-FacePerception_run-3_events.tsv
# G:/WH_working\sub-002\eeg\sub-002_task-FacePerception_run-3_events_temp2.tsv
# G:/WH_working\sub-002\eeg\sub-002_task-FacePerception_run-4_events.tsv
# G:/WH_working\sub-002\eeg\sub-002_task-FacePerception_run-4_events_temp2.tsv
# G:/WH_working\sub-002\eeg\sub-002_task-FacePerception_run-5_events.tsv
# G:/WH_working\sub-002\eeg\sub-002_task-FacePerception_run-5_events_temp2.tsv
# G:/WH_working\sub-002\eeg\sub-002_task-FacePerception_run-6_events.tsv
# G:/WH_working\sub-002\eeg\sub-002_task-FacePerception_run-6_events_temp2.tsv
# G:/WH_working\sub-003\eeg\sub-003_task-FacePerception_run-1_events.tsv
# G:/WH_working\sub-003\eeg\sub-003_task-FacePerception_run-1_events_temp2.tsv
# G:/WH_working\sub-003\eeg\sub-003_task-FacePerception_run-2_events.tsv
# G:/WH_working\sub-003\eeg\sub-003_task-FacePerception_run-2_events_temp2.tsv
# G:/WH_working\sub-003\eeg\sub-003_task-FacePerception_run-3_events.tsv
# G:/WH_working\sub-003\eeg\sub-003_task-FacePerception_run-3_events_temp2.tsv
# G:/WH_working\sub-003\eeg\sub-003_task-FacePerception_run-4_events.tsv
# G:/WH_working\sub-003\eeg\sub-003_task-FacePerception_run-4_events_temp2.tsv
# G:/WH_working\sub-003\eeg\sub-003_task-FacePerception_run-5_events.tsv
# G:/WH_working\sub-003\eeg\sub-003_task-FacePerception_run-5_events_temp2.tsv
# G:/WH_working\sub-003\eeg\sub-003_task-FacePerception_run-6_events.tsv
# G:/WH_working\sub-003\eeg\sub-003_task-FacePerception_run-6_events_temp2.tsv
# G:/WH_working\sub-004\eeg\sub-004_task-FacePerception_run-1_events.tsv
# G:/WH_working\sub-004\eeg\sub-004_task-FacePerception_run-1_events_temp2.tsv
# G:/WH_working\sub-004\eeg\sub-004_task-FacePerception_run-2_events.tsv
# G:/WH_working\sub-004\eeg\sub-004_task-FacePerception_run-2_events_temp2.tsv
# G:/WH_working\sub-004\eeg\sub-004_task-FacePerception_run-3_events.tsv
# G:/WH_working\sub-004\eeg\sub-004_task-FacePerception_run-3_events_temp2.tsv
# G:/WH_working\sub-004\eeg\sub-004_task-FacePerception_run-4_events.tsv
# G:/WH_working\sub-004\eeg\sub-004_task-FacePerception_run-4_events_temp2.tsv
# G:/WH_working\sub-004\eeg\sub-004_task-FacePerception_run-5_events.tsv
# G:/WH_working\sub-004\eeg\sub-004_task-FacePerception_run-5_events_temp2.tsv
# G:/WH_working\sub-004\eeg\sub-004_task-FacePerception_run-6_events.tsv
# G:/WH_working\sub-004\eeg\sub-004_task-FacePerception_run-6_events_temp2.tsv
# G:/WH_working\sub-005\eeg\sub-005_task-FacePerception_run-1_events.tsv
# G:/WH_working\sub-005\eeg\sub-005_task-FacePerception_run-1_events_temp2.tsv
# G:/WH_working\sub-005\eeg\sub-005_task-FacePerception_run-2_events.tsv
# G:/WH_working\sub-005\eeg\sub-005_task-FacePerception_run-2_events_temp2.tsv
# G:/WH_working\sub-005\eeg\sub-005_task-FacePerception_run-3_events.tsv
# G:/WH_working\sub-005\eeg\sub-005_task-FacePerception_run-3_events_temp2.tsv
# G:/WH_working\sub-005\eeg\sub-005_task-FacePerception_run-4_events.tsv
# G:/WH_working\sub-005\eeg\sub-005_task-FacePerception_run-4_events_temp2.tsv
# G:/WH_working\sub-005\eeg\sub-005_task-FacePerception_run-5_events.tsv
# G:/WH_working\sub-005\eeg\sub-005_task-FacePerception_run-5_events_temp2.tsv
# G:/WH_working\sub-005\eeg\sub-005_task-FacePerception_run-6_events.tsv
# G:/WH_working\sub-005\eeg\sub-005_task-FacePerception_run-6_events_temp2.tsv
# G:/WH_working\sub-006\eeg\sub-006_task-FacePerception_run-1_events.tsv
# G:/WH_working\sub-006\eeg\sub-006_task-FacePerception_run-1_events_temp2.tsv
# G:/WH_working\sub-006\eeg\sub-006_task-FacePerception_run-2_events.tsv
# G:/WH_working\sub-006\eeg\sub-006_task-FacePerception_run-2_events_temp2.tsv
# G:/WH_working\sub-006\eeg\sub-006_task-FacePerception_run-3_events.tsv
# G:/WH_working\sub-006\eeg\sub-006_task-FacePerception_run-3_events_temp2.tsv
# G:/WH_working\sub-006\eeg\sub-006_task-FacePerception_run-4_events.tsv
# G:/WH_working\sub-006\eeg\sub-006_task-FacePerception_run-4_events_temp2.tsv
# G:/WH_working\sub-006\eeg\sub-006_task-FacePerception_run-5_events.tsv
# G:/WH_working\sub-006\eeg\sub-006_task-FacePerception_run-5_events_temp2.tsv
# G:/WH_working\sub-006\eeg\sub-006_task-FacePerception_run-6_events.tsv
# G:/WH_working\sub-006\eeg\sub-006_task-FacePerception_run-6_events_temp2.tsv
# G:/WH_working\sub-007\eeg\sub-007_task-FacePerception_run-1_events.tsv
# G:/WH_working\sub-007\eeg\sub-007_task-FacePerception_run-1_events_temp2.tsv
# G:/WH_working\sub-007\eeg\sub-007_task-FacePerception_run-2_events.tsv
# G:/WH_working\sub-007\eeg\sub-007_task-FacePerception_run-2_events_temp2.tsv
# G:/WH_working\sub-007\eeg\sub-007_task-FacePerception_run-3_events.tsv
# G:/WH_working\sub-007\eeg\sub-007_task-FacePerception_run-3_events_temp2.tsv
# G:/WH_working\sub-007\eeg\sub-007_task-FacePerception_run-4_events.tsv
# G:/WH_working\sub-007\eeg\sub-007_task-FacePerception_run-4_events_temp2.tsv
# G:/WH_working\sub-007\eeg\sub-007_task-FacePerception_run-5_events.tsv
# G:/WH_working\sub-007\eeg\sub-007_task-FacePerception_run-5_events_temp2.tsv
# G:/WH_working\sub-007\eeg\sub-007_task-FacePerception_run-6_events.tsv
# G:/WH_working\sub-007\eeg\sub-007_task-FacePerception_run-6_events_temp2.tsv
# G:/WH_working\sub-008\eeg\sub-008_task-FacePerception_run-1_events.tsv
# G:/WH_working\sub-008\eeg\sub-008_task-FacePerception_run-1_events_temp2.tsv
# G:/WH_working\sub-008\eeg\sub-008_task-FacePerception_run-2_events.tsv
# G:/WH_working\sub-008\eeg\sub-008_task-FacePerception_run-2_events_temp2.tsv
# G:/WH_working\sub-008\eeg\sub-008_task-FacePerception_run-3_events.tsv
# G:/WH_working\sub-008\eeg\sub-008_task-FacePerception_run-3_events_temp2.tsv
# G:/WH_working\sub-008\eeg\sub-008_task-FacePerception_run-4_events.tsv
# G:/WH_working\sub-008\eeg\sub-008_task-FacePerception_run-4_events_temp2.tsv
# G:/WH_working\sub-008\eeg\sub-008_task-FacePerception_run-5_events.tsv
# G:/WH_working\sub-008\eeg\sub-008_task-FacePerception_run-5_events_temp2.tsv
# G:/WH_working\sub-008\eeg\sub-008_task-FacePerception_run-6_events.tsv
# G:/WH_working\sub-008\eeg\sub-008_task-FacePerception_run-6_events_temp2.tsv
# G:/WH_working\sub-009\eeg\sub-009_task-FacePerception_run-1_events.tsv
# G:/WH_working\sub-009\eeg\sub-009_task-FacePerception_run-1_events_temp2.tsv
# G:/WH_working\sub-009\eeg\sub-009_task-FacePerception_run-2_events.tsv
# G:/WH_working\sub-009\eeg\sub-009_task-FacePerception_run-2_events_temp2.tsv
# G:/WH_working\sub-009\eeg\sub-009_task-FacePerception_run-3_events.tsv
# G:/WH_working\sub-009\eeg\sub-009_task-FacePerception_run-3_events_temp2.tsv
# G:/WH_working\sub-009\eeg\sub-009_task-FacePerception_run-4_events.tsv
# G:/WH_working\sub-009\eeg\sub-009_task-FacePerception_run-4_events_temp2.tsv
# G:/WH_working\sub-009\eeg\sub-009_task-FacePerception_run-5_events.tsv
# G:/WH_working\sub-009\eeg\sub-009_task-FacePerception_run-5_events_temp2.tsv
# G:/WH_working\sub-009\eeg\sub-009_task-FacePerception_run-6_events.tsv
# G:/WH_working\sub-009\eeg\sub-009_task-FacePerception_run-6_events_temp2.tsv
# G:/WH_working\sub-010\eeg\sub-010_task-FacePerception_run-1_events.tsv
# G:/WH_working\sub-010\eeg\sub-010_task-FacePerception_run-1_events_temp2.tsv
# G:/WH_working\sub-010\eeg\sub-010_task-FacePerception_run-2_events.tsv
# G:/WH_working\sub-010\eeg\sub-010_task-FacePerception_run-2_events_temp2.tsv
# G:/WH_working\sub-010\eeg\sub-010_task-FacePerception_run-3_events.tsv
# G:/WH_working\sub-010\eeg\sub-010_task-FacePerception_run-3_events_temp2.tsv
# G:/WH_working\sub-010\eeg\sub-010_task-FacePerception_run-4_events.tsv
# G:/WH_working\sub-010\eeg\sub-010_task-FacePerception_run-4_events_temp2.tsv
# G:/WH_working\sub-010\eeg\sub-010_task-FacePerception_run-5_events.tsv
# G:/WH_working\sub-010\eeg\sub-010_task-FacePerception_run-5_events_temp2.tsv
# G:/WH_working\sub-010\eeg\sub-010_task-FacePerception_run-6_events.tsv
# G:/WH_working\sub-010\eeg\sub-010_task-FacePerception_run-6_events_temp2.tsv
# G:/WH_working\sub-011\eeg\sub-011_task-FacePerception_run-1_events.tsv
# G:/WH_working\sub-011\eeg\sub-011_task-FacePerception_run-1_events_temp2.tsv
# G:/WH_working\sub-011\eeg\sub-011_task-FacePerception_run-2_events.tsv
# G:/WH_working\sub-011\eeg\sub-011_task-FacePerception_run-2_events_temp2.tsv
# G:/WH_working\sub-011\eeg\sub-011_task-FacePerception_run-3_events.tsv
# G:/WH_working\sub-011\eeg\sub-011_task-FacePerception_run-3_events_temp2.tsv
# G:/WH_working\sub-011\eeg\sub-011_task-FacePerception_run-4_events.tsv
# G:/WH_working\sub-011\eeg\sub-011_task-FacePerception_run-4_events_temp2.tsv
# G:/WH_working\sub-011\eeg\sub-011_task-FacePerception_run-5_events.tsv
# G:/WH_working\sub-011\eeg\sub-011_task-FacePerception_run-5_events_temp2.tsv
# G:/WH_working\sub-011\eeg\sub-011_task-FacePerception_run-6_events.tsv
# G:/WH_working\sub-011\eeg\sub-011_task-FacePerception_run-6_events_temp2.tsv
# G:/WH_working\sub-012\eeg\sub-012_task-FacePerception_run-1_events.tsv
# G:/WH_working\sub-012\eeg\sub-012_task-FacePerception_run-1_events_temp2.tsv
# G:/WH_working\sub-012\eeg\sub-012_task-FacePerception_run-2_events.tsv
# G:/WH_working\sub-012\eeg\sub-012_task-FacePerception_run-2_events_temp2.tsv
# G:/WH_working\sub-012\eeg\sub-012_task-FacePerception_run-3_events.tsv
# G:/WH_working\sub-012\eeg\sub-012_task-FacePerception_run-3_events_temp2.tsv
# G:/WH_working\sub-012\eeg\sub-012_task-FacePerception_run-4_events.tsv
# G:/WH_working\sub-012\eeg\sub-012_task-FacePerception_run-4_events_temp2.tsv
# G:/WH_working\sub-012\eeg\sub-012_task-FacePerception_run-5_events.tsv
# G:/WH_working\sub-012\eeg\sub-012_task-FacePerception_run-5_events_temp2.tsv
# G:/WH_working\sub-012\eeg\sub-012_task-FacePerception_run-6_events.tsv
# G:/WH_working\sub-012\eeg\sub-012_task-FacePerception_run-6_events_temp2.tsv
# G:/WH_working\sub-013\eeg\sub-013_task-FacePerception_run-1_events.tsv
# G:/WH_working\sub-013\eeg\sub-013_task-FacePerception_run-1_events_temp2.tsv
# G:/WH_working\sub-013\eeg\sub-013_task-FacePerception_run-2_events.tsv
# G:/WH_working\sub-013\eeg\sub-013_task-FacePerception_run-2_events_temp2.tsv
# G:/WH_working\sub-013\eeg\sub-013_task-FacePerception_run-3_events.tsv
# G:/WH_working\sub-013\eeg\sub-013_task-FacePerception_run-3_events_temp2.tsv
# G:/WH_working\sub-013\eeg\sub-013_task-FacePerception_run-4_events.tsv
# G:/WH_working\sub-013\eeg\sub-013_task-FacePerception_run-4_events_temp2.tsv
# G:/WH_working\sub-013\eeg\sub-013_task-FacePerception_run-5_events.tsv
# G:/WH_working\sub-013\eeg\sub-013_task-FacePerception_run-5_events_temp2.tsv
# G:/WH_working\sub-013\eeg\sub-013_task-FacePerception_run-6_events.tsv
# G:/WH_working\sub-013\eeg\sub-013_task-FacePerception_run-6_events_temp2.tsv
# G:/WH_working\sub-014\eeg\sub-014_task-FacePerception_run-1_events.tsv
# G:/WH_working\sub-014\eeg\sub-014_task-FacePerception_run-1_events_temp2.tsv
# G:/WH_working\sub-014\eeg\sub-014_task-FacePerception_run-2_events.tsv
# G:/WH_working\sub-014\eeg\sub-014_task-FacePerception_run-2_events_temp2.tsv
# G:/WH_working\sub-014\eeg\sub-014_task-FacePerception_run-3_events.tsv
# G:/WH_working\sub-014\eeg\sub-014_task-FacePerception_run-3_events_temp2.tsv
# G:/WH_working\sub-014\eeg\sub-014_task-FacePerception_run-4_events.tsv
# G:/WH_working\sub-014\eeg\sub-014_task-FacePerception_run-4_events_temp2.tsv
# G:/WH_working\sub-014\eeg\sub-014_task-FacePerception_run-5_events.tsv
# G:/WH_working\sub-014\eeg\sub-014_task-FacePerception_run-5_events_temp2.tsv
# G:/WH_working\sub-014\eeg\sub-014_task-FacePerception_run-6_events.tsv
# G:/WH_working\sub-014\eeg\sub-014_task-FacePerception_run-6_events_temp2.tsv
# G:/WH_working\sub-015\eeg\sub-015_task-FacePerception_run-1_events.tsv
# G:/WH_working\sub-015\eeg\sub-015_task-FacePerception_run-1_events_temp2.tsv
# G:/WH_working\sub-015\eeg\sub-015_task-FacePerception_run-2_events.tsv
# G:/WH_working\sub-015\eeg\sub-015_task-FacePerception_run-2_events_temp2.tsv
# G:/WH_working\sub-015\eeg\sub-015_task-FacePerception_run-3_events.tsv
# G:/WH_working\sub-015\eeg\sub-015_task-FacePerception_run-3_events_temp2.tsv
# G:/WH_working\sub-015\eeg\sub-015_task-FacePerception_run-4_events.tsv
# G:/WH_working\sub-015\eeg\sub-015_task-FacePerception_run-4_events_temp2.tsv
# G:/WH_working\sub-015\eeg\sub-015_task-FacePerception_run-5_events.tsv
# G:/WH_working\sub-015\eeg\sub-015_task-FacePerception_run-5_events_temp2.tsv
# G:/WH_working\sub-015\eeg\sub-015_task-FacePerception_run-6_events.tsv
# G:/WH_working\sub-015\eeg\sub-015_task-FacePerception_run-6_events_temp2.tsv
# G:/WH_working\sub-016\eeg\sub-016_task-FacePerception_run-1_events.tsv
# G:/WH_working\sub-016\eeg\sub-016_task-FacePerception_run-1_events_temp2.tsv
# G:/WH_working\sub-016\eeg\sub-016_task-FacePerception_run-2_events.tsv
# G:/WH_working\sub-016\eeg\sub-016_task-FacePerception_run-2_events_temp2.tsv
# G:/WH_working\sub-016\eeg\sub-016_task-FacePerception_run-3_events.tsv
# G:/WH_working\sub-016\eeg\sub-016_task-FacePerception_run-3_events_temp2.tsv
# G:/WH_working\sub-016\eeg\sub-016_task-FacePerception_run-4_events.tsv
# G:/WH_working\sub-016\eeg\sub-016_task-FacePerception_run-4_events_temp2.tsv
# G:/WH_working\sub-016\eeg\sub-016_task-FacePerception_run-5_events.tsv
# G:/WH_working\sub-016\eeg\sub-016_task-FacePerception_run-5_events_temp2.tsv
# G:/WH_working\sub-016\eeg\sub-016_task-FacePerception_run-6_events.tsv
# G:/WH_working\sub-016\eeg\sub-016_task-FacePerception_run-6_events_temp2.tsv
# G:/WH_working\sub-017\eeg\sub-017_task-FacePerception_run-1_events.tsv
# G:/WH_working\sub-017\eeg\sub-017_task-FacePerception_run-1_events_temp2.tsv
# G:/WH_working\sub-017\eeg\sub-017_task-FacePerception_run-2_events.tsv
# G:/WH_working\sub-017\eeg\sub-017_task-FacePerception_run-2_events_temp2.tsv
# G:/WH_working\sub-017\eeg\sub-017_task-FacePerception_run-3_events.tsv
# G:/WH_working\sub-017\eeg\sub-017_task-FacePerception_run-3_events_temp2.tsv
# G:/WH_working\sub-017\eeg\sub-017_task-FacePerception_run-4_events.tsv
# G:/WH_working\sub-017\eeg\sub-017_task-FacePerception_run-4_events_temp2.tsv
# G:/WH_working\sub-017\eeg\sub-017_task-FacePerception_run-5_events.tsv
# G:/WH_working\sub-017\eeg\sub-017_task-FacePerception_run-5_events_temp2.tsv
# G:/WH_working\sub-017\eeg\sub-017_task-FacePerception_run-6_events.tsv
# G:/WH_working\sub-017\eeg\sub-017_task-FacePerception_run-6_events_temp2.tsv
# G:/WH_working\sub-018\eeg\sub-018_task-FacePerception_run-1_events.tsv
# G:/WH_working\sub-018\eeg\sub-018_task-FacePerception_run-1_events_temp2.tsv
# G:/WH_working\sub-018\eeg\sub-018_task-FacePerception_run-2_events.tsv
# G:/WH_working\sub-018\eeg\sub-018_task-FacePerception_run-2_events_temp2.tsv
# G:/WH_working\sub-018\eeg\sub-018_task-FacePerception_run-3_events.tsv
# G:/WH_working\sub-018\eeg\sub-018_task-FacePerception_run-3_events_temp2.tsv
# G:/WH_working\sub-018\eeg\sub-018_task-FacePerception_run-4_events.tsv
# G:/WH_working\sub-018\eeg\sub-018_task-FacePerception_run-4_events_temp2.tsv
# G:/WH_working\sub-018\eeg\sub-018_task-FacePerception_run-5_events.tsv
# G:/WH_working\sub-018\eeg\sub-018_task-FacePerception_run-5_events_temp2.tsv
# G:/WH_working\sub-018\eeg\sub-018_task-FacePerception_run-6_events.tsv
# G:/WH_working\sub-018\eeg\sub-018_task-FacePerception_run-6_events_temp2.tsv
# G:/WH_working\sub-019\eeg\sub-019_task-FacePerception_run-1_events.tsv
# G:/WH_working\sub-019\eeg\sub-019_task-FacePerception_run-1_events_temp2.tsv
# G:/WH_working\sub-019\eeg\sub-019_task-FacePerception_run-2_events.tsv
# G:/WH_working\sub-019\eeg\sub-019_task-FacePerception_run-2_events_temp2.tsv
# G:/WH_working\sub-019\eeg\sub-019_task-FacePerception_run-3_events.tsv
# G:/WH_working\sub-019\eeg\sub-019_task-FacePerception_run-3_events_temp2.tsv
# G:/WH_working\sub-019\eeg\sub-019_task-FacePerception_run-4_events.tsv
# G:/WH_working\sub-019\eeg\sub-019_task-FacePerception_run-4_events_temp2.tsv
# G:/WH_working\sub-019\eeg\sub-019_task-FacePerception_run-5_events.tsv
# G:/WH_working\sub-019\eeg\sub-019_task-FacePerception_run-5_events_temp2.tsv
# G:/WH_working\sub-019\eeg\sub-019_task-FacePerception_run-6_events.tsv
# G:/WH_working\sub-019\eeg\sub-019_task-FacePerception_run-6_events_temp2.tsv

# %%
#os.remove("demofile.txt")

# remove_list = get_file_list(bids_root_path, types=[".tsv"], suffix="._temp2")
# for file in remove_list:
#     os.remove(file)
#     print(file)
